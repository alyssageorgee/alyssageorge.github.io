# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

file_path = 'statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp'
map_df = gpd.read_file(file_path)

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
df =pd.read_excel('2014 data.xlsx')

# %%
df.head()
# Out:
#                    NAME  Suicide Rates  Depression  Mean of Income
# 0  Kingston upon Thames              4       0.085           41900
# 1               Croydon             36       0.083           31800
# 2               Bromley             28       0.103           39000
# 3              Hounslow              6       0.068           35800
# 4                Ealing             12       0.061           34500

# %%
df_merged = pd.merge(map_df,df)
df_merged.head()
# Out:
#                    NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021   3726.117       0.000         F     None
# 1               Croydon  E09000008   8649.441       0.000         F     None
# 2               Bromley  E09000006  15013.487       0.000         F     None
# 3              Hounslow  E09000018   5658.541      60.755         F     None
# 4                Ealing  E09000009   5554.428       0.000         F     None
#
#   SUB_2006                                           geometry  Suicide Rates  \
# 0     None  POLYGON ((516401.600 160201.800, 516407.300 16...              4
# 1     None  POLYGON ((535009.200 159504.700, 535005.500 15...             36
# 2     None  POLYGON ((540373.600 157530.400, 540361.200 15...             28
# 3     None  POLYGON ((521975.800 178100.000, 521967.700 17...              6
# 4     None  POLYGON ((510253.500 182881.600, 510249.900 18...             12
#
#    Depression  Mean of Income
# 0       0.085           41900
# 1       0.083           31800
# 2       0.103           39000
# 3       0.068           35800
# 4       0.061           34500

# %%
fig, ax = plt.subplots(1, figsize=(10,6))
df_merged.plot(column='Suicide Rates', cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
ax.set_title('Suicide Rates per borough in 2014', fontdict={'fontsize': '25', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Suicide Rates per borough in 2014')
