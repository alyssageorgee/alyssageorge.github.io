# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

file_path = 'statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp'
map_df = gpd.read_file(file_path)

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_excel('2014 data.xlsx')

# %%
df.head()
# Out:
#                    Broughs  Suicide Rates  Depression  Mean of Income
# 0       City of London LB               2       0.060          151000
# 1  Barking and Dagenham LB             13       0.081           24600
# 2                Barnet LB             32       0.079           45500
# 3                Bexley LB             14       0.094           29600
# 4                 Brent LB             25       0.066           29700

# %%
fig, ax = plt.subplots(figsize=(12, 8))
fig
ax.scatter(df['Mean of Income'], df['Suicide Rates'])
for i, text in enumerate(df['Broughs']):
    ax.annotate(text, (df['Mean of Income'][i], df['Suicide Rates'][i]))
