# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel ('All dataset.xlsx')

# %%
plt.rcParams['figure.figsize'] = (5,8)

# %%
sns.boxplot(y=df["Mean Household Income 2019 (annual)"])
plt.savefig('income box plot.png')
