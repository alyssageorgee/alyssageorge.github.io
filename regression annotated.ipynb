# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('All dataset.xlsx')

# %%
df.head()
# Out:
#                    NAME  Depression 2019  \
# 0  Kingston upon Thames            0.085
# 1               Croydon            0.083
# 2               Bromley            0.103
# 3              Hounslow            0.068
# 4               Ealing             0.061
#
#    Anxiety 2019, where 10 = very anxious  Suicide counts (2019)  \
# 0                                   3.28                     18
# 1                                   3.16                     26
# 2                                   2.70                     23
# 3                                   3.17                     27
# 4                                   3.27                     33
#
#    Median Household Income 2019 (annual)  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0                                  35805         NaN         NaN         NaN
# 1                                  27847         NaN         NaN         NaN
# 2                                  33659         NaN         NaN         NaN
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))
fig
ax.scatter(df['Median Household Income 2019 (annual)'], df['Suicide counts (2019)'])
for i, text in enumerate(df['NAME']):
    annot= ax.annotate(text, (df['Median Household Income 2019 (annual)'][i], df['Suicide counts (2019)'][i]))
    annot.set_visible(True)
import numpy as np
df.dropna(inplace=True)
x_values = df['Median Household Income 2019 (annual)']

y_values = df['Depression 2019']

m, b = np.polyfit(x_values, y_values, 1)

plt.plot(x_values, m*x_values+b)

plt.title("Percentage of Depression vs Median Household Income For the London Boroughs in 2019", fontsize=10)


plt.savefig('income vs depression')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3x/w_p1xszx1rg9q2kxl3fzz4n40000gn/T/ipykernel_28056/2217554816.py in <module>
#      11 y_values = df['Depression 2019']
#      12
# ---> 13 m, b = np.polyfit(x_values, y_values, 1)
#      14
#      15 plt.plot(x_values, m*x_values+b)
#
# <__array_function__ internals> in polyfit(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     628         raise TypeError("expected 1D vector for x")
#     629     if x.size == 0:
# --> 630         raise TypeError("expected non-empty vector for x")
#     631     if y.ndim < 1 or y.ndim > 2:
#     632         raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x
