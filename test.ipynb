# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
alyssa = pd.read_csv('data.csv')

# %%
plt.plot(alyssa['Percentage of pupils with LOW achievement at Key Stage 2'], alyssa['Percentage of pupils with MEDIUM achievement at Key Stage 2'])
plt.savefig('weird_graph.png')

# %%
# pandas
# matplotlib
# seaborn
# plotly

# %%
import seaborn as sns

# %%
sns.lmplot(x="Percentage of pupils with LOW achievement at Key Stage 2", y="Percentage of pupils with MEDIUM achievement at Key Stage 2", data=alyssa)
