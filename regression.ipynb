# %%
import pandas as pd
import seaborn as sns

# %%
a1 = pd.read_excel ('sr1.xlsx')

# %%
sns.lmplot(x="Income", y="Suicide Rates", data=a1).set(title='Barking Suicide rate vs Income from 1998 to 2014')
