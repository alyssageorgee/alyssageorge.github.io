# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
a1 = pd.read_excel ('All dataset.xlsx')

# %%
a1['Suicide Rates (2020)'].replace(np.nan, a1['Suicide Rates (2020)'].mean(), inplace=True)

# %%
linregress(a1['Median Household Income 2019 (annual)'], a1['Suicide Rates (2020)'])
# Out:
# LinregressResult(slope=1.4537533989150504e-09, intercept=1.7147516095953053e-05, rvalue=0.38103910088989285, pvalue=0.02868506826481758, stderr=6.335413230656095e-10, intercept_stderr=2.0438492419693962e-05)

# %%
sns.set_theme()
ax=sns.lmplot(x="Median Household Income 2019 (annual)", y="Suicide Rates (2020)", data=a1).set(title='Median Household income vs Suicide Rates')
plt.legend(loc='lower right', labels=['y=1.71*10^-5+1.45*10^-9 x'])
plt.savefig('suicide vs income.png')
