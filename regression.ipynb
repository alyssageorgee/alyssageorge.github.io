# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
a1 = pd.read_excel ('All dataset.xlsx')

# %%
a1['Suicide Rates (2019)'].replace(np.nan, a1['Suicide Rates (2019)'].mean(), inplace=True)

# %%
linregress(a1['Median Household Income 2019 (annual)'], a1['Suicide Rates (2019)'])
# Out:
# LinregressResult(slope=2.3259713307144353e-07, intercept=-2.7216146314036453e-05, rvalue=0.40404041417197184, pvalue=0.019703034075329688, stderr=9.457947786427937e-08, intercept_stderr=0.003051201036159561)

# %%
sns.set_theme()
ax=sns.lmplot(x="Median Household Income 2019 (annual)", y="Suicide Rates (2019)", data=a1).set(title='Median Household income vs Suicide Rates')
plt.legend(loc='lower right', labels=['y=-2.72*10^-5+2.32*10^-7 x'])
plt.savefig('suicide vs income.png')
