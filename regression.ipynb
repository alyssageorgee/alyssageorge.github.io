# %%
import pandas as pd
import seaborn as sns
from scipy import linregress
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/3x/w_p1xszx1rg9q2kxl3fzz4n40000gn/T/ipykernel_38474/2355356334.py in <module>
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 3 from scipy import linregress
#       4 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'linregress' from 'scipy' (/Users/alyssa/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py)

# %%
a1 = pd.read_excel ('All dataset.xlsx')

# %%
sns.set_theme()
ax=sns.lmplot(x="Median Household Income 2019 (annual)", y="Anxiety 2019, where 10 = very anxious", data=a1).set(title='Median Household income vs Anxiety score in 2019')

# %%
linregress(a ='Median Household Income 2019 (annual)', b='Anxiety 2019, where 10 = very anxious', data=a1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3x/w_p1xszx1rg9q2kxl3fzz4n40000gn/T/ipykernel_38474/2659539164.py in <module>
# ----> 1 linregress(a ='Median Household Income 2019 (annual)', b='Anxiety 2019, where 10 = very anxious', data=a1)
#
# NameError: name 'linregress' is not defined

# %%
plt.savefig('income vs Anxiety.png')
