# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
a1 = pd.read_excel ('All dataset.xlsx')

# %%
sns.set_theme()
ax=sns.lmplot(x="Median Household Income 2019 (annual)", y="Anxiety 2019, where 10 = very anxious", data=a1).set(title='Median Household income vs Anxiety score in 2019')

# %%
a1['Median Household Income 2019 (annual)'][28]
# Out:
# 28043

# %%
a1['Anxiety 2019, where 10 = very anxious'].replace(np.nan, a1['Anxiety 2019, where 10 = very anxious'].mean(), inplace=True)

# %%
a1['Anxiety 2019, where 10 = very anxious']
# Out:
# 0     3.280000
# 1     3.160000
# 2     2.700000
# 3     3.170000
# 4     3.270000
# 5     2.440000
# 6     2.830000
# 7     3.150000
# 8     3.040000
# 9     2.850000
# 10    3.710000
# 11    3.040000
# 12    3.320000
# 13    2.630000
# 14    2.780000
# 15    3.230000
# 16    2.940000
# 17    3.070000
# 18    3.380000
# 19    3.280000
# 20    3.040000
# 21    3.260000
# 22    3.230000
# 23    3.350000
# 24    2.880000
# 25    3.130000
# 26    3.680000
# 27    3.340000
# 28    3.150938
# 29    3.520000
# 30    3.180000
# 31    3.330000
# 32    3.620000
# Name: Anxiety 2019, where 10 = very anxious, dtype: float64

# %%
linregress(a1['Median Household Income 2019 (annual)'], a1['Anxiety 2019, where 10 = very anxious'])
# Out:
# LinregressResult(slope=1.0643728181551301e-05, intercept=2.8124050166808856, rvalue=0.20149836056980835, pvalue=0.26081400154634116, stderr=9.292678423543977e-06, intercept_stderr=0.2997883967524376)

# %%
plt.savefig('income vs Anxiety.png')
