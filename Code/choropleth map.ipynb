# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

file_path = 'statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp'
map_df = gpd.read_file(file_path)

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
df =pd.read_excel('All dataset.xlsx')

# %%
df.head()
# Out:
#                    NAME  Depression 2019 (in %)  \
# 0  Kingston upon Thames                   0.085
# 1               Croydon                   0.083
# 2               Bromley                   0.103
# 3              Hounslow                   0.068
# 4               Ealing                    0.061
#
#    Anxiety 2019, where 10 = very anxious  Suicide Rates (2019) (in %)  \
# 0                                   3.28                     0.010140
# 1                                   3.16                     0.006723
# 2                                   2.70                     0.006921
# 3                                   3.17                     0.009944
# 4                                   3.27                     0.009655
#
#    Median Household Income 2019 (annual)  \
# 0                                  35805
# 1                                  27847
# 2                                  33659
# 3                                  29327
# ...

# %%
df_merged = pd.merge(map_df,df)
df_merged.head()
# Out:
#                    NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021   3726.117       0.000         F     None
# 1               Croydon  E09000008   8649.441       0.000         F     None
# 2               Bromley  E09000006  15013.487       0.000         F     None
# 3              Hounslow  E09000018   5658.541      60.755         F     None
# 4              Havering  E09000016  11445.735     210.763         F     None
#
#   SUB_2006                                           geometry  \
# 0     None  POLYGON ((516401.600 160201.800, 516407.300 16...
# 1     None  POLYGON ((535009.200 159504.700, 535005.500 15...
# 2     None  POLYGON ((540373.600 157530.400, 540361.200 15...
# 3     None  POLYGON ((521975.800 178100.000, 521967.700 17...
# 4     None  POLYGON ((549893.900 181459.800, 549894.600 18...
#
#    Depression 2019  Anxiety 2019, where 10 = very anxious  \
# 0            0.085                                   3.28
# ...

# %%
fig, ax = plt.subplots(1, figsize=(10,6))
df_merged.plot(column='Mean Household Income 2019 (annual)', cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
ax.set_title('Mean Household Income in 2019', fontdict={'fontsize': '25', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Mean Household Income in 2019')

# %%
fig.savefig('income map.jpg')
